# %% [markdown]
# ### Set up
# 1. Run `pip install -r requirements.txt`
# 2. Create a .env file
# 3. Create the following variables in the .env file
#     - afsid
#     - GCLB
#     - APP_ID
#         - https://create.appfarm.io/leasi/apps/<APP_ID>
#     - email (your appfarm email)
#     - password (your appfarm password)
#     - chrome_driver_path
#         - https://googlechromelabs.github.io/chrome-for-testing/
#         - download the latest stable chromedriver version for your OS
#         - specify the file path of the chromedriver.exe file
# 4. afsid and GCLB can be found in the cookies of the appfarm website
#     - Log into Leasi app
#     - Inspect element > Network > Refresh
#     - Search for whoami > Headers > Request Headers > Cookie
# 5. afsid and GCLB tokens will change occasionally, so you will need to update them

# %%
import copy
import json
import os
import re
import requests
import subprocess
from bidict import bidict
from collections import Counter, defaultdict
from dotenv import load_dotenv
from enum import Enum
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

class DataSource(Enum):
    DATABASE_CONNECTED = 'database_connected'
    DATA_CONNECTOR = 'data_connector'
    RUNTIME = 'runtime'

class CustomEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Enum):
            return obj.value
        if isinstance(obj, set):
            return list(obj)
        return super().default(obj)

load_dotenv()

APP_ID = os.getenv("APP_ID")
COOKIES = {
    'afsid': os.getenv("afsid"),
    'GCLB': os.getenv("GCLB"),
}
CHROME_DRIVER_PATH = os.getenv("chrome_driver_path")
URL = "https://create.appfarm.io/leasi/apps/81rSrt/data"

os.makedirs("out", exist_ok=True)
os.makedirs("out/result", exist_ok=True)

def fetch_json(url, filename):
    response = requests.get(url, cookies=COOKIES)
    print(response.status_code)
    response = response.json()
    with open(f"./out/{filename}.json", "w") as f:
        json.dump(response, f, indent=4)

def fetch_js(url, filename):
    response = requests.get(url, cookies=COOKIES)
    print(response.status_code)
    response = response.text
    
    pattern = (
        r"window\.AF_APP_" + re.escape(APP_ID) + r"\s*=\s*\{\s*\.\.\.window\.AF_APP_" +
        re.escape(APP_ID) + r",\s*(fn\d+:\(\{resolve,reject\}\)=>\{.*?\})\s*\}"
    )
    
    replacement = r"module.exports = {\1}"
    
    response = re.sub(
        pattern,
        replacement,
        response,
        flags=re.DOTALL
    )

    with open(f"./out/{filename}.js", "w", encoding="utf-8") as f:
        f.write(response)
    
    subprocess.run(
        ["node", "format.js"],
        capture_output=True,
        text=True
    )
    

def load_data(filename):
    try:
        with open(f"./out/{filename}.json", "r") as f:
            data = json.load(f)
        return data
    except FileNotFoundError:
        return None

# %% [markdown]
# Load in data

# %%
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/actions', 'actions')
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/app', 'app')
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/datasources', 'datasources')
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/enumeratedtypes', 'enumeratedtypes')
fetch_js(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/functions', 'functions')
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/layout', 'layout')
fetch_json(f'https://leasi-dev.appfarm.app/api/v1/apps/{APP_ID}/metadata/objectclasses', 'objectclasses')
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [markdown]
# Finds the object class ID of the given object with the nodeName. If an object class is not referenced in another object class, this approach does not work.
#
# NOTE: Some nodes have been renamed so there can be multiple object class IDs mapping to the same nodeName. It should normally be the one with the highest occurance.

# %%
object_classes = load_data('objectclasses')['objectClasses']

def get_referenceId(obj):
    result = Counter()
    for object_class in object_classes:
        for item in object_class.get('properties', []):
            if item.get('nodeName') == obj:
                result[item.get('referenceId')] += 1
    return result

get_referenceId('product')
# Out:
# Counter({'UKweiZ': 19, 'xqH59g': 1, None: 1})

# %% [markdown]
# Groups all data sources with the same object class id.
#
# NOTE: There is no name associated with the object class id, so you will need to manually find the name of the object class. Object classs name can be inferred from the data source names.

# %%
data_sources = load_data('datasources')['dataSources']

def group_data_sources_by_object_class_id():
    result = defaultdict(list)
    for data_source in data_sources.values():
        if data_source.get('name') == 'GENERATED':
            continue
        if data_source.get('dataSourceType') == 'OBJECT_CLASS':
            data_type = DataSource.DATABASE_CONNECTED
            if data_source.get('dataConnector'):
                data_type = DataSource.DATA_CONNECTOR
            elif data_source.get('local'):
                data_type = DataSource.RUNTIME
            result[data_source.get('objectClassId')].append({
                'id': data_source.get('id'),
                'name': data_source.get('name'),
                'cardinality': data_source.get('cardinality'),
                'data_source_type': data_type,
                'runtime_properties': set([k for k, v in data_source.get('properties', {}).items() if v.get('runtime', False)])
            })
    return result

grouped_data_sources = group_data_sources_by_object_class_id()

# %%
with open('./out/result/grouped_data_sources.json', 'w') as f:
    json.dump(grouped_data_sources, f, indent=4, cls=CustomEncoder)

# %% [markdown]
# Web scraper to map object class id to object class name.

# %%
# Load page
service = Service(CHROME_DRIVER_PATH)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(10)
driver.get(URL)

# %%
# Login
login_with_google = driver.find_element(By.CSS_SELECTOR, ".MuiButtonBase-root.MuiButton-root.MuiButton-contained")
login_with_google.click()

email = driver.find_element(By.XPATH, '//*[@id="identifierId"]')
email.send_keys(os.getenv("email"))
next_button = driver.find_element(By.XPATH, '//*[@id="identifierNext"]/div/button')
next_button.click()

password = driver.find_element(By.XPATH, '//*[@id="password"]/div[1]/div/div[1]/input')
password.send_keys(os.getenv("password"))
next_button = driver.find_element(By.XPATH, '//*[@id="passwordNext"]/div/button')
next_button.click()

# %%
object_class_names = load_data('object_class_names') or {}

def open_search():
    search = driver.find_element(By.XPATH, '//*[@id="app"]/div/div/main/div/div/div/div[1]/div[2]/div[1]/div[1]/div/div[2]/button')
    search.click()

def clear_search():
    search_clear = driver.find_element(By.XPATH, '//*[@id="app"]/div/div/main/div[1]/div/div/div[1]/div[2]/div[1]/div[1]/div/div[2]/button')
    search_clear.click()

def search_menu_item(name):
    search_input = driver.find_element(By.XPATH, '//*[@id="app"]/div/div/main/div/div/div/div[1]/div[2]/div[1]/div[1]/div/div[1]/input')
    search_input.send_keys(name)

    menu_items = driver.find_element(By.XPATH, '//*[@id="app"]/div/div/main/div/div/div/div[1]/div[2]/div[2]/div/div[1]/ul').find_elements(By.TAG_NAME, "div")
    for menu_item in menu_items:
        if menu_item.text == name:
            menu_item.click()
            break

def get_object_class_name(data_source_id):
    object_class_name = driver.find_element(By.XPATH, f'//*[@id="p_{data_source_id}_objectClassId"]/div/span')
    return object_class_name.text

def map_object_class_names(grouped_data_sources):
    result = {}
    for object_class_id, data_sources in grouped_data_sources.items():
        if object_class_id in object_class_names:
            continue
        open_search()
        search_menu_item(data_sources[0]['name'])
        clear_search()
        object_class_name = get_object_class_name(data_sources[0]['id'])
        result[object_class_id] = object_class_name
    return result

object_class_names |= map_object_class_names(grouped_data_sources)
driver.quit()

# %%
with open('./out/object_class_names.json', 'w') as f:
    json.dump(object_class_names, f, indent=4, cls=CustomEncoder)

# %% [markdown]
# Finds all actions associated with the data source that satisfy `is_valid_node`.

# %%
actions = load_data('actions')['actions']

def is_valid_node(data_source_type, action_node):
    if data_source_type == DataSource.DATABASE_CONNECTED:
        return action_node.get('nodeType') in {'create_object', 'modify_object', 'delete_object'}
    elif data_source_type == DataSource.DATA_CONNECTOR:
        return action_node.get('nodeType') in {'create_object', 'modify_object', 'delete_object'}
    elif data_source_type == DataSource.RUNTIME:
        return action_node.get('nodeType') in {'persist'}

def find_action(action, action_nodes, object_data_source, disabled=False):
    result = []
    for action_node in action_nodes:
        is_disabled = disabled or action_node.get('disabled', False)
        if action_node.get('dataSourceId') == object_data_source.get('id'):
            if is_valid_node(object_data_source.get('data_source_type'), action_node):
                result.append({
                    'action_id': action.get('id'),
                    'action_name': action.get('name'),
                    'action_node_id': action_node.get('id'),
                    'action_node_name': action_node.get('name'),
                    'action_node_type': action_node.get('nodeType'),
                    'disabled': is_disabled,
                    'update_values': action_node.get('defaultValues')
                })
        if action_node.get('children'):
            result += find_action(action, action_node['children'], object_data_source, is_disabled)
    return result

def get_actions(object_data_sources):
    result = []
    for object_data_source in object_data_sources:
        actions_for_data_source = []
        for action in actions.values():
            actions_for_data_source += find_action(action, action['actionNodes'], object_data_source)
        object_data_source['actions'] = actions_for_data_source
        result.append(object_data_source)
    return result

object_class_names = bidict(object_class_names)
object_data_sources = grouped_data_sources[object_class_names.inv['Product']]
objects = get_actions(object_data_sources)
objects
# Out:
# [{'id': 'Wxg7pV',
#   'name': 'Product (all)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'I0o1Rl', 'WPYl7R', 'Wy6uCU', 'x4ikri'},
#   'actions': [{'action_id': '2tw120',
#     'action_name': 'Orders - Searchbar',
#     'action_node_id': 'JhkXEH',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'Wy6uCU',
#       'value': False,
#       'nodeName': 'calenderSearch'}]},
#    {'action_id': '2tw120',
#     'action_name': 'Orders - Searchbar',
#     'action_node_id': 'TlZB4a',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'Wy6uCU',
#       'value': True,
#       'nodeName': 'calenderSearch'}]},
#    {'action_id': '8eGZDT',
#     'action_name': '2. Resources - Product Search - On Value Change',
#     'action_node_id': 'WgYvMq',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'Wy6uCU',
#       'value': False,
#       'nodeName': 'calenderSearch'}]},
#    {'action_id': '8eGZDT',
#     'action_name': '2. Resources - Product Search - On Value Change',
#     'action_node_id': 'DZXwHc',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'Wy6uCU',
#       'value': False,
#       'nodeName': 'calenderSearch'}]},
#    {'action_id': 'DhJvM4',
#     'action_name': 'Productcard - mark as delivered',
#     'action_node_id': 'd43TdH',
#     'action_node_name': 'Update Object - Set storage facility to default',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'pqLNMA',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'Wxg7pV',
#         'propertyId': '0DglEw',
#         'nodeName': 'storageFacilityDefault'}},
#       'nodeName': 'storageFacilityCurrent'},
#      {'propertyId': 'tBpiNY',
#       'value': 'aktiv',
#       'nodeName': 'operationalStatus'}]},
#    {'action_id': '5AZUP3',
#     'action_name': '3. Order Overview - Status: I Leie',
#     'action_node_id': 't60npt',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'pqLNMA',
#       'value': None,
#       'nodeName': 'storageFacilityCurrent'}]},
#    {'action_id': 'jczWCd',
#     'action_name': 'Move Product: Return to default',
#     'action_node_id': 'Jyvs0g',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'pqLNMA',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'Wxg7pV',
#         'propertyId': '0DglEw',
#         'nodeName': 'storageFacilityDefault'}},
#       'nodeName': 'storageFacilityCurrent'}]},
#    {'action_id': 'kefeRD',
#     'action_name': 'productcard - set status to bestit',
#     'action_node_id': 'nJAUxi',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'tBpiNY',
#       'value': 'aktiv',
#       'nodeName': 'operationalStatus'}]},
#    {'action_id': 'QOApag',
#     'action_name': '2. Resources - Machine Overview - Close Selected Objects Drawer',
#     'action_node_id': 'liI5ar',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'nUhtfr',
#     'action_name': '8. Settings - Choose products to bulk edit',
#     'action_node_id': '7QI6iU',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': True,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'nUhtfr',
#     'action_name': '8. Settings - Choose products to bulk edit',
#     'action_node_id': '9l0OQ1',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'hT17Hg',
#     'action_name': '8. Settings - Remove product from bulk edit',
#     'action_node_id': 'oRXsFg',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'DFoTum',
#     'action_name': '8. Settings - 2.8 Edit machines in bulk: On View Load',
#     'action_node_id': 'mwkCQS',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'Ahz1fb',
#     'action_name': '8. Settings - save changes in machine bulk edit',
#     'action_node_id': 'pUVdbN',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'eoH3LB',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '6YFuSo',
#         'propertyId': 'eoH3LB',
#         'nodeName': 'group'}},
#       'nodeName': 'group'},
#      {'propertyId': 'tBpiNY',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '6YFuSo',
#         'propertyId': 'tBpiNY',
#         'nodeName': 'operationalStatus',
#         'enumeratedTypeId': 'mDuwGL'}},
#       'nodeName': 'operationalStatus'},
#      {'propertyId': '0DglEw',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '6YFuSo',
#         'propertyId': '0DglEw',
#         'nodeName': 'storageFacilityDefault'}},
#       'nodeName': 'storageFacilityDefault'},
#      {'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'},
#      {'propertyId': 'NnezNG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '6YFuSo',
#         'propertyId': 'NnezNG',
#         'nodeName': 'productOwner'}},
#       'nodeName': 'productOwner'},
#      {'propertyId': 'x440bG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'Wxg7pV',
#         'propertyId': 'x440bG',
#         'nodeName': 'productPriceLog',
#         'objectClassId': 'D1VKhD'},
#        'valueProsessors': [{'id': 'fYOSqC',
#          'operation': 'reference_add_selection',
#          'refSelection': {'type': 'dataBinding',
#           'dataBinding': {'dataSourceId': 'jsvHaI',
#            'selectionMode': 'all',
#            'propertyId': True,
#            'nodeName': '_id'}}}]},
#       'nodeName': 'productPriceLog'},
#      {'propertyId': 'f4CmQR',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '6YFuSo',
#         'propertyId': 'f4CmQR',
#         'nodeName': 'name'}},
#       'nodeName': 'name'}]},
#    {'action_id': 'P94kat',
#     'action_name': 'Product - Machine info reference',
#     'action_node_id': 'XknQik',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'zqnQyv',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'ounz2x',
#         'propertyId': True,
#         'nodeName': '_id'}},
#       'nodeName': 'machineInfo'}]},
#    {'action_id': 'C5b7nF',
#     'action_name': 'Webhook - Update product number',
#     'action_node_id': 'kA4KC1',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'WN8CC7',
#       'value': {'type': 'functionValue',
#        'functionValue': {'id': '4c63aad2',
#         'functionParameters': [{'id': 'hE11h1',
#           'name': 'productNumber',
#           'functionParameterType': 'self',
#           'selectionType': 'all',
#           'propertyId': 'WN8CC7',
#           'nodeName': 'productNumber'}]}},
#       'nodeName': 'productNumber'}]},
#    {'action_id': 'dOJCeX',
#     'action_name': '2. Resources - Machine Overview - Open Machine Edit Dialog',
#     'action_node_id': 'Ccu12U',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': True,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'BUGXu9',
#     'action_name': '2. Resources - Bulk Edit - Close Dialog',
#     'action_node_id': 'GpVdVC',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': 'BUGXu9',
#     'action_name': '2. Resources - Bulk Edit - Close Dialog',
#     'action_node_id': 'H9wrty',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'I0o1Rl',
#       'value': False,
#       'nodeName': 'isSelectedForBulkEdit'}]},
#    {'action_id': '8OhcDN',
#     'action_name': 'Import VS - Prices',
#     'action_node_id': 'eaKhII',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'x440bG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '2ePU20',
#         'propertyId': True,
#         'nodeName': '_id'}},
#       'nodeName': 'productPriceLog'}]},
#    {'action_id': 'WjWHJ4',
#     'action_name': '2. Resources - Price Model - save changes',
#     'action_node_id': 'iAzq5D',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'x440bG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'Wxg7pV',
#         'propertyId': 'x440bG',
#         'nodeName': 'productPriceLog',
#         'objectClassId': 'D1VKhD'},
#        'valueProsessors': [{'id': 'shcxWD',
#          'operation': 'reference_add_selection',
#          'refSelection': {'type': 'dataBinding',
#           'dataBinding': {'dataSourceId': 'Tt1Goq',
#            'selectionMode': 'selected',
#            'propertyId': True,
#            'nodeName': '_id'}}}]},
#       'nodeName': 'productPriceLog'}]},
#    {'action_id': 'naxx65',
#     'action_name': 'Set accounting ID',
#     'action_node_id': 'fil4KP',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': '3h1G3h',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'Wxg7pV',
#         'propertyId': 'WN8CC7',
#         'nodeName': 'productNumber'}},
#       'nodeName': 'accountingID'}]},
#    {'action_id': 'sX4dkb',
#     'action_name': 'Dev Tools: Give Machine Info to Accessories',
#     'action_node_id': 'IvB7D3',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': [{'propertyId': 'zqnQyv',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'WevNzn',
#         'propertyId': True,
#         'nodeName': '_id'}},
#       'nodeName': 'machineInfo'}]},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': '2Qhs4X',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': '6YFuSo',
#   'name': 'Product (runtime)',
#   'cardinality': 'ONE',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': {'7MFZgS', 'I05xJQ'},
#   'actions': [{'action_id': 'DhJvM4',
#     'action_name': 'Productcard - mark as delivered',
#     'action_node_id': 'lRnIam',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': 'uh8zTp',
#     'action_name': '8. Settings - Save existing machine',
#     'action_node_id': 'T5JCgE',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': '578UJ1',
#     'action_name': '8. Settings - Save new machine',
#     'action_node_id': 'IqCSSo',
#     'action_node_name': 'Persist Objects - persist product (runtime) ',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'vfuCVH',
#     'action_name': 'Move Product - Save location',
#     'action_node_id': 'E5zvo7',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': 'wsbGjs',
#     'action_name': '8. Settings - Save new accessory',
#     'action_node_id': 'sLxdgV',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'eNXTjd',
#     'action_name': '8. Settings - Save bulk product',
#     'action_node_id': 'cc47Ek',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'yQmW1q',
#   'name': 'Products (runtime) (Import)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': 'OhfDIg',
#     'action_name': 'Save data - Import Machines',
#     'action_node_id': 'm4UOIp',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'aHcohb',
#     'action_name': 'Dev Tools - Import - Update machineinfo TEST (import)',
#     'action_node_id': 'yCdsLe',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': '3VO7Ef',
#     'action_name': 'Save data - Import Accessories',
#     'action_node_id': 'uw9pzg',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'mvFou1',
#     'action_name': 'Save data - Import Machines Sigve',
#     'action_node_id': '8xZSsa',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'i7MjA0',
#   'name': 'Product (for selected group)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'vyjWyg',
#   'name': 'Product (for user projects)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'Yb7YyX',
#   'name': 'Product (search, active only)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'tCpCMc'},
#   'actions': []},
#  {'id': 'WB03Bw',
#   'name': 'Product (Machine Overview)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'56N8sB', '5uJM5d'},
#   'actions': [{'action_id': 'OytEZ7',
#     'action_name': '2. Resources - Price Models - multiple price edit',
#     'action_node_id': 'TItDIm',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'x440bG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'WB03Bw',
#         'propertyId': 'x440bG',
#         'nodeName': 'productPriceLog',
#         'objectClassId': 'D1VKhD'},
#        'valueProsessors': [{'id': 'FF8cab',
#          'operation': 'reference_add_selection',
#          'refSelection': {'type': 'dataBinding',
#           'dataBinding': {'dataSourceId': 'Tt1Goq',
#            'selectionMode': 'selected',
#            'propertyId': True,
#            'nodeName': '_id'}}}]},
#       'nodeName': 'productPriceLog'}]},
#    {'action_id': 'K2mafr',
#     'action_name': '2. Resources - Price Models - store new unsaved price',
#     'action_node_id': '4BgYxi',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'x440bG',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'WB03Bw',
#         'propertyId': 'x440bG',
#         'nodeName': 'productPriceLog',
#         'objectClassId': 'D1VKhD'},
#        'valueProsessors': [{'id': 'HtVpPG',
#          'operation': 'reference_add_selection',
#          'refSelection': {'type': 'dataBinding',
#           'dataBinding': {'dataSourceId': 'PJA3xs',
#            'selectionMode': 'selected',
#            'propertyId': True,
#            'nodeName': '_id'}}}]},
#       'nodeName': 'productPriceLog'}]},
#    {'action_id': 'VOFKNW',
#     'action_name': '2. Resources - Machine Overview: On View Loaded',
#     'action_node_id': 'Uy9WUp',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': '56N8sB',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': 'XSBdGt',
#         'propertyId': 'gqu5zF',
#         'nodeName': 'companyProject'}},
#       'nodeName': 'companyProject'}]},
#    {'action_id': 'V1hXm1',
#     'action_name': '2. Resources - Machine Overview - Add accessory info to product',
#     'action_node_id': 'Ze5aHl',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': [{'propertyId': 'xiY8bn',
#       'value': 'tilbehor',
#       'nodeName': 'productCategory'}]}]},
#  {'id': 'ORSWBN',
#   'name': 'Product - Accessories (Order Dialog Search)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'kKiPCG'},
#   'actions': []},
#  {'id': '6sKP9i',
#   'name': 'Product (all accessories)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'Cbiz0u',
#   'name': 'Product (all accessories) (suggested)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'vu11x5',
#   'name': 'Product (runtime) (many)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': {'fXXbh7'},
#   'actions': [{'action_id': 'RBimQI',
#     'action_name': '3. Order Overview - Update Status',
#     'action_node_id': 'ZhzLeV',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'RBimQI',
#     'action_name': '3. Order Overview - Update Status',
#     'action_node_id': 'ZrXppQ',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': 'RBimQI',
#     'action_name': '3. Order Overview - Update Status',
#     'action_node_id': '83OQGx',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'vfuCVH',
#     'action_name': 'Move Product - Save location',
#     'action_node_id': 'BZL6Me',
#     'action_node_name': 'Persist Objects - PERSIST MOVED TO 3. Order Overview - Update Status',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': '6hZDin',
#     'action_name': '3. Order overview - set directly in returnert',
#     'action_node_id': 'zLYsGI',
#     'action_node_name': 'Persist Objects - PERSIST MOVED TO 3. Order Overview - Update Status',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': 'Hh7n9P',
#     'action_name': 'Save data - Import Price Logs',
#     'action_node_id': '72PoNF',
#     'action_node_name': 'Persist Objects - Persist the products that has new price logs on them',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'xoNrEO',
#     'action_name': 'Import VS - Save Prices',
#     'action_node_id': 'mn828k',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'drzTB2',
#     'action_name': 'Dev Tools: Set utgått',
#     'action_node_id': 'esclHh',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'OjmvDM',
#   'name': 'Product (all bulk products)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'rGHb8t'},
#   'actions': []},
#  {'id': 'N0eIta',
#   'name': 'Product (Maintenance Activity View)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'TGF7dJ',
#   'name': 'Product (search results work order filter)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': '8V4wCt',
#   'name': 'Products (Collaboration) (runtime, many)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': {'OZuMfx'},
#   'actions': []},
#  {'id': 'KdLgeF',
#   'name': 'Product search test',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'hsdg6g',
#   'name': 'Product (runtime, for import)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': 'tnrs9U',
#     'action_name': 'Import Skanska Price Model',
#     'action_node_id': 'oJaMnI',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': 'cVAzK8',
#     'action_name': 'Dev Tools: Duplicate VS',
#     'action_node_id': 'leOzvW',
#     'action_node_name': 'Persist Objects',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None}]},
#  {'id': 'nPah37',
#   'name': 'Product (graphQL, test)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'bdPFWm',
#   'name': 'Order Line (non for period)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'a177xM',
#   'name': 'Product (runtime, for webhook)',
#   'cardinality': 'ONE',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'ln2LXa',
#   'name': '_Product (data connector)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATA_CONNECTOR: 'data_connector'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'MX1kXk',
#     'action_node_name': 'Create Object - data connector',
#     'action_node_type': 'create_object',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': '9nSlP0',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': False,
#     'update_values': None},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'UwDr7g',
#     'action_node_name': 'Delete Objects',
#     'action_node_type': 'delete_object',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'uH2GMW',
#   'name': '_Product (runtime, one)',
#   'cardinality': 'ONE',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'vMMiBr',
#     'action_node_name': 'Persist Objects - runtime, one',
#     'action_node_type': 'persist',
#     'disabled': True,
#     'update_values': None}]},
#  {'id': 'rilOTD',
#   'name': '_Product (runtime, many)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'PnYce3',
#     'action_node_name': 'Persist Objects - runtime, many',
#     'action_node_type': 'persist',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'WEytsN',
#   'name': 'Product (runtime, many, for webhook)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.RUNTIME: 'runtime'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': '3AZdMx',
#   'name': '_Product (database connected, many)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'L8yJRW',
#     'action_node_name': 'Create Object - database connected, many',
#     'action_node_type': 'create_object',
#     'disabled': False,
#     'update_values': [{'propertyId': '3h1G3h',
#       'value': {'type': 'dataBinding',
#        'dataBinding': {'dataSourceId': '3AZdMx',
#         'propertyId': '3h1G3h',
#         'nodeName': 'accountingID'}},
#       'nodeName': 'accountingID'}]},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'mcnoB0',
#     'action_node_name': 'Delete Objects',
#     'action_node_type': 'delete_object',
#     'disabled': False,
#     'update_values': None}]},
#  {'id': 'GrpNhw',
#   'name': '_Product (database connected, one)',
#   'cardinality': 'ONE',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': [{'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'EiKJv0',
#     'action_node_name': 'Create Object - database connected, one',
#     'action_node_type': 'create_object',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'svk2AX',
#     'action_node_name': 'Update Object',
#     'action_node_type': 'modify_object',
#     'disabled': True,
#     'update_values': None},
#    {'action_id': '7WxZiR',
#     'action_name': '_pls dont delete me, used for testing',
#     'action_node_id': 'NuVcSa',
#     'action_node_name': 'Delete Objects',
#     'action_node_type': 'delete_object',
#     'disabled': True,
#     'update_values': None}]},
#  {'id': 'EY3ffC',
#   'name': 'Product (product card)',
#   'cardinality': 'ONE',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'uBDBqy',
#   'name': 'Product (for project)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'DECVQ0'},
#   'actions': []},
#  {'id': 'Zn2O5g',
#   'name': 'Product (external)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': {'MNrPdX'},
#   'actions': []},
#  {'id': 'c44EOO',
#   'name': 'Product (add-on)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []},
#  {'id': 'JJsqIh',
#   'name': 'Product (for order line runtime many)',
#   'cardinality': 'MANY',
#   'data_source_type': <DataSource.DATABASE_CONNECTED: 'database_connected'>,
#   'runtime_properties': set(),
#   'actions': []}]

# %%
# simple dfs to analyse action.json
node_type = Counter()

def dfs(actions, f):
    def helper(action_nodes, action, f):
        for action_node in action_nodes:
            f(action_node, action)
            helper(action_node.get('children', []), action, f)
    for action in actions.values():
        helper(action.get('actionNodes', []), action, f)

def count_node_type(action_node, *args):
    node_type[action_node.get('nodeType')] += 1

dfs(actions, count_node_type)
node_type
# Out:
# Counter({'modify_object': 1648,
#          'if': 1163,
#          'set_selection': 816,
#          'read_objects': 574,
#          'delete_object': 553,
#          'persist': 444,
#          'run_action': 398,
#          'create_object': 379,
#          'end_execution': 276,
#          'close_dialog': 216,
#          'foreach': 205,
#          'open_dialog': 155,
#          'navigate': 151,
#          'simple_web_request': 116,
#          'open_confirm_dialog': 115,
#          'set_data_source_attributes': 90,
#          'block': 72,
#          'open_snackbar': 51,
#          'catch_exception': 40,
#          'open_popover': 38,
#          'import_data_from_file': 35,
#          'sleep': 35,
#          'run_code': 31,
#          'duplicate_objects': 31,
#          'console_log': 30,
#          'close_popover': 24,
#          'run_service': 24,
#          'modify_user_account': 24,
#          'upload_file': 22,
#          'sort_objects': 20,
#          'open_url': 16,
#          'throw_exception': 10,
#          'export_data': 9,
#          'aggregate_data': 9,
#          'next_iteration': 8,
#          'exit_loop': 6,
#          'toggle_drawer': 5,
#          'generate_document': 3,
#          'set_user_account_image': 2,
#          'send_email': 2,
#          'while': 2,
#          'log_out': 1,
#          'create_user_account': 1})

# %%
# process result
def get_action_counts(objects):
    result = []
    for obj in objects:
        counts = len(obj.get('actions'))
        if counts == 0:
            continue
        result.append({
            'name': obj.get('name'),
            'counts': counts
        })
    return result

def remove_disabled(objects):
    result = []
    for obj in objects:
        obj = copy.deepcopy(obj)
        actions = obj.get('actions')
        actions = [action for action in actions if not action.get('disabled')]
        if len(actions) > 0:
            obj['actions'] = actions
            result.append(obj)
    return result

def remove_runtime_properties(objects, object_data_sources):
    object_data_sources = {obj.get('id'): obj for obj in object_data_sources}
    result = []
    for obj in objects:
        object_data_source = object_data_sources.get(obj.get('id'))
        actions = []
        for action in obj.get('actions', []):
            action = copy.deepcopy(action)
            if action['action_node_type'] != 'modify_object':
                actions.append(action)
                continue
            runtime_properties = object_data_source.get('runtime_properties')
            update_values = action.get('update_values') or []
            action['update_values'] = [item for item in update_values if item.get('propertyId') not in runtime_properties]
            if len(action['update_values']) > 0:
                actions.append(action)
        obj['actions'] = actions
        result.append(obj)
    return result

def generate_link(objects):
    objects = copy.deepcopy(objects)
    for obj in objects:
        for action in obj.get('actions', []):
            action['url'] = f"https://create.appfarm.io/leasi/apps/{APP_ID}/actions/{action['action_id']}/{action['action_node_id']}"
    return objects

# %%
result = generate_link(remove_runtime_properties(remove_disabled(objects), object_data_sources))
get_action_counts(result)
# Out:
# [{'name': 'Product (all)', 'counts': 8},
#  {'name': 'Product (runtime)', 'counts': 4},
#  {'name': 'Products (runtime) (Import)', 'counts': 3},
#  {'name': 'Product (Machine Overview)', 'counts': 3},
#  {'name': 'Product (runtime) (many)', 'counts': 5},
#  {'name': 'Product (runtime, for import)', 'counts': 1},
#  {'name': '_Product (data connector)', 'counts': 2},
#  {'name': '_Product (runtime, many)', 'counts': 1},
#  {'name': '_Product (database connected, many)', 'counts': 2}]

# %%
# save result
with open('./out/result/result.json', 'w') as f:
    json.dump(result, f, cls=CustomEncoder, indent=4)

# %% [markdown]
# ### Findings
#
# functions.json: ids map to a function called in any of the other json files with "functionValue" as its key.
